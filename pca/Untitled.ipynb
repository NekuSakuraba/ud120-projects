# %%
import matplotlib.pyplot as plt
import pickle as pck
import sys
sys.path.append("../tools/")

from feature_format import featureFormat, targetFeatureSplit

# %%
data = pck.load(open('../final_project/final_project_dataset.pkl','r'))

# %%
data
# Out:
# {'ALLEN PHILLIP K': {'bonus': 4175000,
#   'deferral_payments': 2869717,
#   'deferred_income': -3081055,
#   'director_fees': 'NaN',
#   'email_address': 'phillip.allen@enron.com',
#   'exercised_stock_options': 1729541,
#   'expenses': 13868,
#   'from_messages': 2195,
#   'from_poi_to_this_person': 47,
#   'from_this_person_to_poi': 65,
#   'loan_advances': 'NaN',
#   'long_term_incentive': 304805,
#   'other': 152,
#   'poi': False,
#   'restricted_stock': 126027,
#   'restricted_stock_deferred': -126027,
#   'salary': 201955,
#   'shared_receipt_with_poi': 1407,
#   'to_messages': 2902,
#   'total_payments': 4484442,
#   'total_stock_value': 1729541},
#  'BADUM JAMES P': {'bonus': 'NaN',
#   'deferral_payments': 178980,
#   'deferred_income': 'NaN',
#   'director_fees': 'NaN',
#   'email_address': 'NaN',
#   'exercised_stock_options': 257817,
#   'expenses': 3486,
#   'from_messages': 'NaN',
#   'from_poi_to_this_person': 'NaN',
#   'from_this_person_to_poi': 'NaN',
# ...

# %%
n_data = [ [data[item]['bonus'],data[item]['long_term_incentive']] for item in data]

# %%
plt.scatter(salary,exercised_stock_options)
plt.show()

# %%
### the input features we want to use 
### can be any key in the person-level dictionary (salary, director_fees, etc.) 
feature_1 = "salary"
feature_2 = "exercised_stock_options"
feature_3 = "total_payments"
poi  = "poi"
features_list = [poi, feature_1, feature_2, feature_3]
d = featureFormat(data, features_list )
poi, finance_features = targetFeatureSplit( d )

# %%
n_data = []
for f1, f2, f3 in finance_features:
    plt.scatter( f1, f2 )
    n_data.append([f1,f2])
plt.show()

# %%
d.plot.scatter(x=0, y=1)
plt.show()

# %%
for item in d:
    plt.scatter(item[0], item[1], color='k')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-153-2a63d3b1b92e> in <module>()
#       1 for item in d:
# ----> 2     plt.scatter(item[0], item[1], color='k')
#       3 plt.show()
#
# IndexError: invalid index to scalar variable.

# %%
from pandas import DataFrame
import pandas as pd

# %%
import numpy as np

# %%
n_data = DataFrame(np.array([[f1],[f2]]).T)

# %%
np.isnan([np.NaN,1])
# Out:
# array([ True, False], dtype=bool)

# %%
d = DataFrame(n_data)

# %%
idx = d[d[0]=='NaN'].index

# %%
d = d.dropna()

# %%
d
# Out:
#            0        1
# 1    1200000  1586055
# 4    1500000  1617011
# 7    2600000   694862
# 12    850000   831809
# 13    700000   476451
# 17   1100000  1725545
# 21    850000   540751
# 25   2000000   554422
# 27    250000   180250
# 29   1000000   369721
# 34    200000  2234774
# 36   1700000    69223
# 41    800000   602671
# 42   1000000  1387399
# 43   8000000  2035380
# 45    425000   415657
# 48    750000   304805
# 52   1500000   554422
# 55    600000   335349
# 57   3000000   808346
# 58   1100000   554422
# 60   3000000  1294981
# 61    100000   554422
# 63    200000   175000
# 65   7000000  3600000
# 66    750000   175000
# 67    750000   100000
# 69    325000   275000
# 72    700000   150000
# 75   1150000   983346
# 76   1350000   974293
# 78    350000   556416
# 83    750000  1105218
# 85   1300000  1736055
# 87   1250000   375304
# 88   1750000  1617011
# 89    400000   323466
# 95   5600000  1920000
# 103  1000000   300000
# 105   325000   200000
# ...

# %%
for i in idx:
    d.loc[i][0] = np.nan

# %%
d.head()
# Out:
#          0        1
# 0   600000      NaN
# 1  1200000  1586055
# 2   350000      NaN
# 3      NaN      NaN
# 4  1500000  1617011

# %%
n_data
# Out:
# [[600000, 'NaN'],
#  [1200000, 1586055],
#  [350000, 'NaN'],
#  ['NaN', 'NaN'],
#  [1500000, 1617011],
#  [325000, 'NaN'],
#  ['NaN', 'NaN'],
#  [2600000, 694862],
#  ['NaN', 'NaN'],
#  [400000, 'NaN'],
#  ['NaN', 'NaN'],
#  [788750, 'NaN'],
#  [850000, 831809],
#  [700000, 476451],
#  ['NaN', 461912],
#  ['NaN', 'NaN'],
#  [1200000, 'NaN'],
#  [1100000, 1725545],
#  [250000, 'NaN'],
#  ['NaN', 256191],
#  ['NaN', 'NaN'],
#  [850000, 540751],
#  [3100000, 'NaN'],
#  ['NaN', 'NaN'],
#  ['NaN', 'NaN'],
#  [2000000, 554422],
#  ['NaN', 'NaN'],
#  [250000, 180250],
#  ['NaN', 'NaN'],
#  [1000000, 369721],
#  [700000, 'NaN'],
#  ['NaN', 'NaN'],
#  [700000, 'NaN'],
#  ['NaN', 'NaN'],
#  [200000, 2234774],
#  ['NaN', 'NaN'],
#  [1700000, 69223],
#  ['NaN', 'NaN'],
#  ['NaN', 'NaN'],
#  ['NaN', 'NaN'],
#  ['NaN', 'NaN'],
#  [800000, 602671],
#  [1000000, 1387399],
#  [8000000, 2035380],
#  ['NaN', 'NaN'],
#  [425000, 415657],
#  ['NaN', 'NaN'],
#  ['NaN', 'NaN'],
#  [750000, 304805],
# ...

# %%
for item in n_data:
    if np.isnan(item[0]) or np.isnan(item[1]):
        print item
        break
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-9b6da493e1db> in <module>()
#       1 for item in n_data:
# ----> 2     if np.isnan(item[0]) or np.isnan(item[1]):
#       3         print item
#       4         break
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
def doPCA(data):
    from sklearn.decomposition import PCA
    pca = PCA(n_components=2)
    pca.fit(data)
    return pca

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
minmax = MinMaxScaler()

# %%
d1 = [i[1] for i in n_data]

# %%
d2 = minmax.fit_transform(d2)
# Out:
# C:\Program Files\Anaconda3\envs\py27\lib\site-packages\sklearn\preprocessing\data.py:324: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# C:\Program Files\Anaconda3\envs\py27\lib\site-packages\sklearn\preprocessing\data.py:359: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)

# %%
d2
# Out:
# array([ 0.13924051,  0.17721519,  0.3164557 ,  0.09493671,  0.07594937,
#         0.12658228,  0.09493671,  0.24050633,  0.01898734,  0.11392405,
#         0.01265823,  0.20253165,  0.08860759,  0.11392405,  1.        ,
#         0.04113924,  0.08227848,  0.17721519,  0.06329114,  0.36708861,
#         0.12658228,  0.36708861,  0.        ,  0.01265823,  0.87341772,
#         0.08227848,  0.08227848,  0.02848101,  0.07594937,  0.13291139,
#         0.15822785,  0.03164557,  0.08227848,  0.15189873,  0.14556962,
#         0.20886076,  0.03797468,  0.69620253,  0.11392405,  0.02848101,
#         0.51582278,  0.06329114,  0.        ,  0.11392405,  0.02531646,
#         0.05063291,  0.03797468,  0.09493671,  0.06329114,  0.08860759,
#         0.24050633,  0.30379747,  0.07594937,  0.02531646,  0.10126582,
#         0.11392405,  0.06329114])

# %%
d1 = np.array(d1)

# %%
d1
# Out:
# array([1586055, 1617011,  694862,  831809,  476451, 1725545,  540751,
#         554422,  180250,  369721, 2234774,   69223,  602671, 1387399,
#        2035380,  415657,  304805,  554422,  335349,  808346,  554422,
#        1294981,  554422,  175000, 3600000,  175000,  100000,  275000,
#         150000,  983346,  974293,  556416, 1105218, 1736055,  375304,
#        1617011,  323466, 1920000,  300000,  200000,  304805,  422158,
#         156250,  694862,   75000,  304805,  125000,  375304,  556416,
#         484000, 1617011,  374347,  300000,  275000,  769862,  350000,
#          71023])

# %%
d3 = DataFrame(np.array([d2,d1]).T)

# %%
d3
# Out:
#            0          1
# 0   0.139241  1586055.0
# 1   0.177215  1617011.0
# 2   0.316456   694862.0
# 3   0.094937   831809.0
# 4   0.075949   476451.0
# 5   0.126582  1725545.0
# 6   0.094937   540751.0
# 7   0.240506   554422.0
# 8   0.018987   180250.0
# 9   0.113924   369721.0
# 10  0.012658  2234774.0
# 11  0.202532    69223.0
# 12  0.088608   602671.0
# 13  0.113924  1387399.0
# 14  1.000000  2035380.0
# 15  0.041139   415657.0
# 16  0.082278   304805.0
# 17  0.177215   554422.0
# 18  0.063291   335349.0
# 19  0.367089   808346.0
# 20  0.126582   554422.0
# 21  0.367089  1294981.0
# 22  0.000000   554422.0
# 23  0.012658   175000.0
# 24  0.873418  3600000.0
# 25  0.082278   175000.0
# 26  0.082278   100000.0
# 27  0.028481   275000.0
# 28  0.075949   150000.0
# 29  0.132911   983346.0
# 30  0.158228   974293.0
# 31  0.031646   556416.0
# 32  0.082278  1105218.0
# 33  0.151899  1736055.0
# 34  0.145570   375304.0
# 35  0.208861  1617011.0
# 36  0.037975   323466.0
# ...

# %%
pca = doPCA(d3)
print pca.explained_variance_ratio_
first_pc = pca.components_[0]
second_pc = pca.components_[1]

transformed_data = pca.transform(d3)
for ii, jj in zip(transformed_data, d3):
    plt.scatter(first_pc[0]**ii[0], first_pc[1]**[0], color='r')
    plt.scatter(second_pc[0]**ii[0], second_pc[1]**[0], color='c')
    #plt.scatter(jj[0], jj[1], color='b')

plt.xlabel('bonus')
plt.ylabel('long-term incentive')
plt.show()
# Out:
# [  1.00000000e+00   4.95323008e-14]

# %%
n_data = d.as_matrix()

# %%
transformed_data
# Out:
# array([[ -8.57095702e+05,   1.70817407e-01],
#        [ -8.88051702e+05,   1.38362512e-01],
#        [  3.40972982e+04,  -1.65307098e-01],
#        [ -1.02849702e+05,   8.06310155e-02],
#        [  2.52508298e+05,   3.62541968e-02],
#        [ -9.96585702e+05,   2.08348205e-01],
#        [  1.88208298e+05,   2.87322379e-02],
#        [  1.74537298e+05,  -1.14399696e-01],
#        [  5.48709298e+05,   4.04003922e-02],
#        [  3.59238298e+05,  -2.07515958e-02],
#        [ -1.50581470e+06,   4.13073273e-01],
#        [  6.59736298e+05,  -1.62941222e-01],
#        [  1.26288298e+05,   4.61023550e-02],
#        [ -6.58439702e+05,   1.60711357e-01],
#        [ -1.30642070e+06,  -6.09822598e-01],
#        [  3.13302298e+05,   6.02240981e-02],
#        [  4.24154298e+05,  -6.81248413e-04],
#        [  1.74537298e+05,  -5.11085565e-02],
#        [  3.93610298e+05,   2.37524177e-02],
#        [ -7.93867018e+04,  -1.95704589e-01],
#        [  1.74537298e+05,  -4.75645108e-04],
# ...
